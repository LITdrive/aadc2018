# %% [markdown]
# # openDrive2CSV
# converts a openDrive-map to a CSV Map with all possible routs, in the order they are able to drive

# %% [markdown]
# #### the drivable points will be stored in a csv, the order determines the direction in which those points can be driven
# |road_id|lane_id|nr|x|y|
# |--|-------------------------------|-----|----|
# |0|0|0|0.23|0.12|
# |0|0|1|0.25|0.12|
# |0|0|3|0.28|0.12|
# |1|0|0|0.40|0.21|
#
# #### the junctions or connections will be stored in a seperate file
# |id-from|id-to|
# |--|--|
# |0|1|

# %%
from lxml import etree
from opendriveparser import parse_opendrive
from opendrive2lanelet import Network
import matplotlib.pyplot as plt
import pandas as pd

# %%
def loadOpenDriveFile(path):
    # Load road network and print some statistics
    fh = open(path, 'r')
    openDriveXml = parse_opendrive(etree.parse(fh).getroot())
    fh.close()
    
    roadNetwork = Network()
    roadNetwork.loadOpenDrive(openDriveXml)
    
    print("Name: {}<br>Version: {}<br>Date: {}<br><br>OpenDRIVE Version {}.{}<br><br>Number of roads: {}<br>Total length of road network: {:.2f} meters".format(
            openDriveXml.header.name if openDriveXml.header.name else "<i>unset</i>",
            openDriveXml.header.version,
            openDriveXml.header.date,
            openDriveXml.header.revMajor,
            openDriveXml.header.revMinor,
            len(openDriveXml.roads),
            sum([road.length for road in openDriveXml.roads])))
    
    return roadNetwork, openDriveXml

# %%
path = 'C:/Users/Phil/Google Drive/JKU AADC/Resources/OpenDRIVE/openDRIVE_example_maps/'
#path = '/home/aadc/AADC/src/aadcUserPython/OpenDRIVE/openDRIVE_example_maps/'
easyFile = 'aadc2018#1.xodr'
ourMap = 'ourMAP.xodr'
comp = 'aadc2017#competition.xodr'
path2 = 'C:/Users/Phil/Downloads/odr_sample/'
huge = 'KA-Suedtangente-Vires.xodr'
testEvent = 'E:/JKU/AADC/git/src/aadcUserPython/OpenDRIVE/openDRIVE_example_maps/AADC_2018_Testevent_maps/aadc2018#test#track#003.xodr'

fn = path+comp
roadNetwork, openDriveXml = loadOpenDriveFile(testEvent)
# Out:
# Name: <i>unset</i><br>Version: None<br>Date: None<br><br>OpenDRIVE Version 1.4<br><br>Number of roads: 170<br>Total length of road network: 2053.51 meters

# %%
roads = openDriveXml.roads
r = roads[0]
r.length
# Out:
# 15.521355730841455

# %%
import numpy as np
for r in roads: # for every road-segment
    for ls in r.lanes.laneSections: # for every laneSection (subparts of a road-segment)
        #print(ls.sPos)
        for asdf in ls.allLanes:
            asdf.type
        for ll in ls.leftLanes: # for right and left lanes
            #print(ll.laneTypes) #shows all types; eg sidewalk, dringing, parking, ...
            print(ll.type,end=', ') #shows the type
            for w in ll.widths:
                #print(w.sOffset)
                #print(w.length)
                #print(w.idx)
                dss=np.asarray([0,1,2,3,4,5])
                ws = np.dot(w.coeffs, np.asarray([np.ones(len(dss)), dss**1, dss**2, dss**3]))
                #print( w )
# Out:
# driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving, driving,
# ...

# %%
from opendriveparser.elements.roadPlanView import ParamPoly3
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib notebook

#gtk

#plt.figure(figsize=(9,9))
plt.figure(figsize=(28,14))

RES = 0.5 # Resolution along which the points should be computed in meters [m]

points = pd.DataFrame(columns=['id','road_id','lane_id','nr','x','y'])
ctr = 0
connections = pd.DataFrame()

for rNr, r in enumerate(roads):
    # """ Calculate position and tangent at sPos ""
    ss = np.asarray( range(0,int(r.length*1000),int(RES*1000)) )/1000 #points along the track which should be calculated
    xs= np.zeros(len(ss))
    ys= np.zeros(len(ss))
    degs= np.zeros(len(ss))
    
    
    for idx, ds in enumerate(ss):
        [x,y],t = r.planView.calc(ds) #t is degrees of line in radians
        
        xs[idx]=x
        ys[idx]=y
        degs[idx]=t #radiant
    
    s=''
    if r.junction==None: #it has to be a road
        for ls in r.lanes.laneSections: #for all lanes in all laneSections
            # right Lanes:
            lsdic = {}
            lsdic[-1] = ls.rightLanes
            lsdic[1] = ls.leftLanes
            for ldx in [-1, 1]: #right and left lane
                for l in lsdic[ldx]:
                    if l.type == 'driving' or l.type=='onRamp' or l.type=='offRamp' or l.type=='exit':# or l.type == 'onRamp':
                        sum_ws = 0
                        for width in l.widths:
                            # only at special points from sPos to length
                            ssw = np.zeros(len(ss))
                            indizes = ss<(width.length)#(ss>width.sOffset)&(ss<(width.sOffset+width.length))
                            index2 = (ss>=width.sOffset)&(ss<=(width.sOffset+width.length))
                            ssw[index2]=ss[0:sum(index2)]

                            # width = a + b*ds + c*ds^2 + d*ds^3
                            ws = np.dot(width.coeffs, np.asarray([np.ones(len(ssw)), ssw**1, ssw**2, ssw**3]))

                            offset = (ws/2+sum_ws)*ldx
                            dx=np.sin(degs)*offset 
                            dy=np.cos(degs)*-1*offset
                            
                            plt.plot(np.asarray(xs)+dx,np.asarray(ys)+dy,'.r') # points for driving
                            
                            #arrow for the direction
                            #ldx for direction --> right side =-1
                            # for the left side the indizes have to be turned
                            # interchange count up or down ;)
                            drt = ldx*-1
                            xx = (xs+dx)[::drt]
                            yy = (ys+dy)[::drt]
                            for ii in range(len(xx)-1):        
                                plt.arrow(xx[ii], yy[ii],
                                          xx[ii+1]-xx[ii], yy[ii+1]-yy[ii],
                                          head_width=0.4, head_length=0.4, fc='y', ec='y')
                            
                            poi = pd.DataFrame()
                            poi['road_id']=np.ones(len(xx))*r.id
                            poi['lane_id']=np.ones(len(xx))*width.idx
                            poi['id']=np.ones(len(xx))*ctr
                            ctr+=1
                            print(ctr,end=' - ')
                            poi['x']=xx
                            poi['y']=yy
                            poi['nr']=np.asarray(range(len(xx)))
                            points = points.append(poi)
                            
                            #outer line
                            offset = (ws+sum_ws)*ldx
                            dx=np.sin(degs)*offset
                            dy=np.cos(degs)*-1*offset
                            plt.plot(np.asarray(xs)+dx,np.asarray(ys)+dy,'k')
                        sum_ws+=ws                
        plt.plot(xs,ys,'k--') #middle line
    else:
        s+='j'
        plt.plot(xs,ys,'g.')
        # arrow for direction of junction
        for ii in range(0,len(xs)-1):
            plt.arrow(xs[ii],ys[ii],
                      xs[ii+(1)]-(xs[ii]),
                      ys[ii+(1)]-(ys[ii]),
                      head_width=0.5, head_length=0.5, fc='y', ec='y')
            
        poi = pd.DataFrame()
        poi['id']=np.ones(len(xs))*ctr
        ctr+=1
        print(ctr,end=' - ')
        poi['x']=xs
        poi['y']=ys
        poi['road_id']=np.ones(len(xs))*r.id
        poi['lane_id']=np.ones(len(xs))*0
        poi['nr']=np.asarray(range(len(xs)))
        points = points.append(poi)
    plt.text(xs[3]+0.2,ys[3]+0.2,s+str(r.id))#+'  '+str(degs[3]*180/np.pi))

plt.show()
plt.xlim([0,28*8])
plt.ylim([0,14*8])
# Out:
# <img src="data:image/png;base64,..." width="2798.002835157406">
# 1 - 2 - 3 - 4 - 5 - 6 -
# E:\Portable-Apps\PortableApps\Anaconda\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# ...

# %%
plt.savefig()

# %%
plt.figure()
plt.scatter(points.x,points.y,c=points.id,cmap='rainbow')
for idd in list(set(points.id)):
    x_pos = points[points.id==idd].x.values[0]
    y_pos = points[points.id==idd].y.values[0]
    plt.text(x_pos,y_pos,str(idd))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.0006474859123">

# %%
points
# Out:
#        id  lane_id nr  road_id           x           y
# 0     0.0      0.0  0    166.0   94.458062   68.969051
# 1     0.0      0.0  1    166.0   92.539420   70.752154
# 2     0.0      0.0  2    166.0   91.234732   72.802759
# 3     0.0      0.0  3    166.0   90.478648   74.984350
# 4     0.0      0.0  4    166.0   90.126426   77.197702
# 5     0.0      0.0  5    166.0   90.021408   79.408717
# 0     1.0      0.0  0    166.0   94.020796   79.457690
# 1     1.0      0.0  1    166.0   94.108069   77.563607
# 2     1.0      0.0  2    166.0   94.366746   75.911011
# 3     1.0      0.0  3    166.0   94.847439   74.509435
# 4     1.0      0.0  4    166.0   95.612697   73.303327
# 5     1.0      0.0  5    166.0   96.804420   72.199984
# 0     2.0      0.0  0    164.0  104.033158   22.058783
# 1     2.0      0.0  1    164.0  105.622867   22.225103
# 2     2.0      0.0  2    164.0  107.172857   22.702417
# 3     2.0      0.0  3    164.0  108.658501   23.461428
# ...

# %%
points.to_csv(fn+'_points.csv',sep=';',index=False)

# %%
def plotMap(roads):
    for r in roads:
        xs=[]
        ys=[]
        degs=[]
        for idx, i in enumerate(range(0,50)):
            [x,y],t = r.planView.calc(i) #t is degrees of line in radians
            xs.append(x)
            ys.append(y)
            degs.append(t) #in radians

            # stop when calc outputs the same pos
            if idx == 0:
                print(r.id,end='-')
            else: 
                if x*100==xs[idx-1]*100 and y*100==ys[idx-1]*100:
                    break
        s=''
        if r.junction==None: #it has to be a road
            s+=('r')
            for c, offset in [['k',-4],['r:',-2],['g:',2],['k',4]]:
                dx=np.sin(degs)*offset
                dy=np.cos(degs)*-1*offset
                plt.plot(np.asarray(xs)+dx,np.asarray(ys)+dy,c)
                if c=='g:': #right side
                    plt.arrow(xs[0]+dx[0],
                              ys[0]+dy[0],
                              xs[3]+dx[3]-(xs[0]+dx[0]),
                              ys[3]+dy[3]-(ys[0]+dy[0]),
                              head_width=0.5, head_length=0.5, fc='k', ec='k')
                if c=='r:':
                    plt.arrow(xs[3]+dx[3],
                              ys[3]+dy[3],
                              xs[0]+dx[0]-(xs[3]+dx[3]),
                              ys[0]+dy[0]-(ys[3]+dy[3]),
                              head_width=0.5, head_length=0.5, fc='k', ec='k')
            plt.plot(xs,ys,'k--') #middle line

        else: 
            s+='j'
            plt.plot(xs,ys,'g:')
        plt.text(xs[3]+0.2,ys[3]+0.2,s+str(r.id))#+'  '+str(degs[3]*180/np.pi))

# %%
roads[3].planView.calc(0)
# Out:
# (array([ 96.02357835,  20.03245629]), 1.4794064503282248e-05)

# %%
geometry.calc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-233-c10cf651da05> in <module>()
# ----> 1 geometry.calc
#
# NameError: name 'geometry' is not defined

# %%
#fh = open("test/opendrive-1.xodr", 'r')
loc = 'C:/Users/Phil/Google Drive/JKU AADC/Resources/OpenDRIVE/'
fh = open(loc+'openDRIVE_example_maps/aadc2018#1.xodr', 'r')
openDrive = parse_opendrive(etree.parse(fh).getroot())
fh.close()

roadNetwork = Network()
roadNetwork.loadOpenDrive(openDrive)

scenario = roadNetwork.exportCommonRoadScenario()

fh = open("test/opendrive-1.xml", "wb")
fh.write(scenario.export_to_string())
fh.close()

# %%
import os
import sys
from lxml import etree
from opendriveparser import parse_opendrive

# OpenDriveFile
fn = 'openDRIVE_example_maps/aadc2018#1.xodr'

with open(fn, 'r') as fh:
    parser = etree.XMLParser()
    rootNode = etree.parse(fh, parser).getroot()
    roadNetwork = parse_opendrive(rootNode)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-67-17456c21204b> in <module>()
#       7 fn = 'openDRIVE_example_maps/aadc2018#1.xodr'
#       8
# ----> 9 with open(fn, 'r') as fh:
#      10     parser = etree.XMLParser()
#      11     rootNode = etree.parse(fh, parser).getroot()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'openDRIVE_example_maps/aadc2018#1.xodr'

# %%
roadNetwork.roads

# %%
mapImg = 'C:/Users/Phil/Google Drive/JKU AADC/Resources/OpenDRIVE/ourMap.jpg'
from PIL import Image                                                                                
img = Image.open(mapImg)
plt.imshow(np.asarray(img))
plotMap(roads)
# Out:
# 55-54-57-45-42-41-39-44-36-35-27-21-23-30-19-18-15-28-14-43-12-17-10-8-6-5-22-4-56-40-7-16-11-29-2-9-1-

# %% [markdown]
# # only plot drivable lane

# %%
def getTrajectory(roads):
    plt.figure(figsize=(50,50))
    for cc, r in enumerate(roads):
        lw=3
        xs=[]
        ys=[]
        degs=[]
        for idx, i in enumerate(range(0,int(r.length*10))):
            i=i/10
            [x,y],t = r.planView.calc(i) #t is degrees of line in radians
            xs.append(x)
            ys.append(y)
            degs.append(t) #in radians

        s=''
        if r.junction==None: #it has to be a road
            s+=('r')
            for c, offset in enumerate([-2,2]): #['k',4]['k',4]
                dx=np.sin(degs)*offset
                dy=np.cos(degs)*-1*offset
            #actual plotting    
                plt.plot(np.asarray(xs)+dx,np.asarray(ys)+dy,c=str(cc*2+c+1),linewidth=lw)
        else: 
            s+='j'
            #actual plotting 
            plt.plot(xs,ys,c=str(cc*2+1),linewidth=lw)

    plt.axis('off')
    plt.savefig('asdf')

# %%
# %matplotlib inline
getTrajectory(roads)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-82618b60e77f> in <module>()
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 getTrajectory(roads)
#
# <ipython-input-13-ed516c6f422c> in getTrajectory(roads)
#      17             s+=('r')
#      18             for c, offset in enumerate([-2,2]): #['k',4]['k',4]
# ---> 19                 dx=np.sin(degs)*offset
#      20                 dy=np.cos(degs)*-1*offset
#      21             #actual plotting
#
# NameError: name 'np' is not defined

# %%
from PIL import Image
img = np.asarray(Image.open("asdf.png"))

plt.imshow(img)

# %%
trajArray = np.abs( img.sum(axis=2)-np.median(img.sum(axis=2)))
np.savez_compressed('trajectoryArray',trajArray)

# %%
trajArray.shape
# Out:
# (3600, 3600)

# %%
# %matplotlib inline
plt.figure(figsize=(8,8))
plt.imshow(trajArray[2000:2500,2000:2500],cmap='viridis')

# %% [markdown]
# # get fat bitmask of map

# %%
from opendriveparser.elements.roadPlanView import ParamPoly3
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib notebook

#gtk

plt.figure(figsize=(28/2,14/2))

RES = 0.2 # Resolution along which the points should be computed in meters [m]

points = pd.DataFrame(columns=['id','road_id','lane_id','nr','x','y'])
ctr = 0
connections = pd.DataFrame()

for rNr, r in enumerate(roads):
    # """ Calculate position and tangent at sPos ""
    ss = np.asarray( range(0,int(r.length*1000),int(RES*1000)) )/1000 #points along the track which should be calculated
    xs= np.zeros(len(ss))
    ys= np.zeros(len(ss))
    degs= np.zeros(len(ss))
    
    
    for idx, ds in enumerate(ss):
        [x,y],t = r.planView.calc(ds) #t is degrees of line in radians
        
        xs[idx]=x
        ys[idx]=y
        degs[idx]=t #radiant
    
    s=''
    if r.junction==None: #it has to be a road
        for ls in r.lanes.laneSections: #for all lanes in all laneSections
            # right Lanes:
            lsdic = {}
            lsdic[-1] = ls.rightLanes
            lsdic[1] = ls.leftLanes
            for ldx in [-1, 1]: #right and left lane
                for l in lsdic[ldx]:
                    if l.type == 'driving' or l.type=='onRamp' or l.type=='offRamp' or l.type=='exit':# or l.type == 'onRamp':
                        sum_ws = 0
                        for width in l.widths:
                            # only at special points from sPos to length
                            ssw = np.zeros(len(ss))
                            indizes = ss<(width.length)#(ss>width.sOffset)&(ss<(width.sOffset+width.length))
                            index2 = (ss>=width.sOffset)&(ss<=(width.sOffset+width.length))
                            ssw[index2]=ss[0:sum(index2)]

                            # width = a + b*ds + c*ds^2 + d*ds^3
                            ws = np.dot(width.coeffs, np.asarray([np.ones(len(ssw)), ssw**1, ssw**2, ssw**3]))

                            offset = (ws/2+sum_ws)*ldx
                            dx=np.sin(degs)*offset 
                            dy=np.cos(degs)*-1*offset
                            
                            plt.plot(np.asarray(xs)+dx,np.asarray(ys)+dy,'k',linewidth=15)#r. # points for driving
                            
                            #arrow for the direction
                            #ldx for direction --> right side =-1
                            # for the left side the indizes have to be turned
                            # interchange count up or down ;)
                            drt = ldx*-1
                            xx = (xs+dx)[::drt]
                            yy = (ys+dy)[::drt]
                            for ii in range(len(xx)-1):        
                                plt.arrow(xx[ii], yy[ii],
                                          xx[ii+1]-xx[ii], yy[ii+1]-yy[ii],
                                          head_width=0.4, head_length=0.4, fc='y', ec='y')
                            
                            poi = pd.DataFrame()
                            poi['road_id']=np.ones(len(xx))*r.id
                            poi['lane_id']=np.ones(len(xx))*width.idx
                            poi['id']=np.ones(len(xx))*ctr
                            ctr+=1
                            print(ctr,end=' - ')
                            poi['x']=xx
                            poi['y']=yy
                            poi['nr']=np.asarray(range(len(xx)))
                            points = points.append(poi)
                            
                            #outer line
                            offset = (ws+sum_ws)*ldx
                            dx=np.sin(degs)*offset
                            dy=np.cos(degs)*-1*offset
                            plt.plot(np.asarray(xs)+dx,np.asarray(ys)+dy,'k')
                        sum_ws+=ws                
        plt.plot(xs,ys,'k--') #middle line
    else:
        s+='j'
        plt.plot(xs,ys,'k',linewidth=15) #
        # arrow for direction of junction
        for ii in range(0,len(xs)-1):
            plt.arrow(xs[ii],ys[ii],
                      xs[ii+(1)]-(xs[ii]),
                      ys[ii+(1)]-(ys[ii]),
                      head_width=0.5, head_length=0.5, fc='y', ec='y')
            
        poi = pd.DataFrame()
        poi['id']=np.ones(len(xs))*ctr
        ctr+=1
        print(ctr,end=' - ')
        poi['x']=xs
        poi['y']=ys
        poi['road_id']=np.ones(len(xs))*r.id
        poi['lane_id']=np.ones(len(xs))*0
        poi['nr']=np.asarray(range(len(xs)))
        points = points.append(poi)
    #plt.text(xs[3]+0.2,ys[3]+0.2,s+str(r.id))#+'  '+str(degs[3]*180/np.pi))

plt.show()
plt.xlim([0,28*8])
plt.ylim([0,14*8])
# Out:
# <img src="data:image/png;base64,..." width="1399.001417578703">
# 1 - 2 - 3 - 4 -
# E:\Portable-Apps\PortableApps\Anaconda\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# ...

# %%
plt.savefig('testevent_map_bitmap.png')
